# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

# %%
iris = load_iris()

X = pd.DataFrame(iris.data)
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled.shape
# Out:
# (150, 4)

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)

X_pca = pca.fit_transform(X_scaled)

X_pca.shape
# Out:
# (150, 2)

# %%
print("Explained varaince ratio :",pca.explained_variance_ratio_)

# it tell us the infomation capture by Pc1 $ pc2
# Out:
# Explained varaince ratio : [0.72962445 0.22850762]

# %%
# eigem vector
print(pca.components_)
# Out:
# [[ 0.52106591 -0.26934744  0.5804131   0.56485654]
#  [ 0.37741762  0.92329566  0.02449161  0.06694199]]

# %%
plt.figure(figsize = (8,6))

plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=y
)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA using iris data")
# Out:
# Text(0.5, 1.0, 'PCA using iris data')
